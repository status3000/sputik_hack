# %%
# Общие библиотеки
import pandas as pd 
import numpy as np
import glob
from tqdm import tqdm
import cv2
import os
from sklearn.model_selection import train_test_split
import json
from math import sin, cos

# Для создания и обучения модели
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from torchsummary import summary

# Для работы с изображениями
import cv2
from PIL import Image

# Для визуализации
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/submission.zip

# %%
# !unzip "/content/drive/MyDrive/test_dataset_test.zip" -d "/content/drive/MyDrive/sputnik/test"
# Out:
# Archive:  /content/drive/MyDrive/test_dataset_test.zip
#   inflating: /content/drive/MyDrive/sputnik/test/1199.png
#   inflating: /content/drive/MyDrive/sputnik/test/1200.png
#   inflating: /content/drive/MyDrive/sputnik/test/3.png
#   inflating: /content/drive/MyDrive/sputnik/test/4.png
#   inflating: /content/drive/MyDrive/sputnik/test/5.png
#   inflating: /content/drive/MyDrive/sputnik/test/10.png
#   inflating: /content/drive/MyDrive/sputnik/test/11.png
#   inflating: /content/drive/MyDrive/sputnik/test/13.png
#   inflating: /content/drive/MyDrive/sputnik/test/15.png
#   inflating: /content/drive/MyDrive/sputnik/test/18.png
#   inflating: /content/drive/MyDrive/sputnik/test/20.png
#   inflating: /content/drive/MyDrive/sputnik/test/21.png
#   inflating: /content/drive/MyDrive/sputnik/test/22.png
#   inflating: /content/drive/MyDrive/sputnik/test/31.png
#   inflating: /content/drive/MyDrive/sputnik/test/33.png
#   inflating: /content/drive/MyDrive/sputnik/test/39.png
#   inflating: /content/drive/MyDrive/sputnik/test/42.png
#   inflating: /content/drive/MyDrive/sputnik/test/45.png
#   inflating: /content/drive/MyDrive/sputnik/test/46.png
#   inflating: /content/drive/MyDrive/sputnik/test/48.png
#   inflating: /content/drive/MyDrive/sputnik/test/51.png
#   inflating: /content/drive/MyDrive/sputnik/test/53.png
#   inflating: /content/drive/MyDrive/sputnik/test/54.png
#   inflating: /content/drive/MyDrive/sputnik/test/65.png
#   inflating: /content/drive/MyDrive/sputnik/test/70.png
#   inflating: /content/drive/MyDrive/sputnik/test/72.png
#   inflating: /content/drive/MyDrive/sputnik/test/73.png
#   inflating: /content/drive/MyDrive/sputnik/test/77.png
#   inflating: /content/drive/MyDrive/sputnik/test/80.png
#   inflating: /content/drive/MyDrive/sputnik/test/87.png
#   inflating: /content/drive/MyDrive/sputnik/test/88.png
#   inflating: /content/drive/MyDrive/sputnik/test/92.png
#   inflating: /content/drive/MyDrive/sputnik/test/93.png
#   inflating: /content/drive/MyDrive/sputnik/test/105.png
#   inflating: /content/drive/MyDrive/sputnik/test/107.png
#   inflating: /content/drive/MyDrive/sputnik/test/112.png
#   inflating: /content/drive/MyDrive/sputnik/test/113.png
#   inflating: /content/drive/MyDrive/sputnik/test/116.png
#   inflating: /content/drive/MyDrive/sputnik/test/117.png
#   inflating: /content/drive/MyDrive/sputnik/test/120.png
#   inflating: /content/drive/MyDrive/sputnik/test/122.png
#   inflating: /content/drive/MyDrive/sputnik/test/125.png
#   inflating: /content/drive/MyDrive/sputnik/test/126.png
#   inflating: /content/drive/MyDrive/sputnik/test/133.png
#   inflating: /content/drive/MyDrive/sputnik/test/137.png
#   inflating: /content/drive/MyDrive/sputnik/test/139.png
#   inflating: /content/drive/MyDrive/sputnik/test/140.png
#   inflating: /content/drive/MyDrive/sputnik/test/143.png
#   inflating: /content/drive/MyDrive/sputnik/test/144.png
#   inflating: /content/drive/MyDrive/sputnik/test/145.png
#   inflating: /content/drive/MyDrive/sputnik/test/152.png
#   inflating: /content/drive/MyDrive/sputnik/test/153.png
#   inflating: /content/drive/MyDrive/sputnik/test/155.png
#   inflating: /content/drive/MyDrive/sputnik/test/158.png
#   inflating: /content/drive/MyDrive/sputnik/test/160.png
#   inflating: /content/drive/MyDrive/sputnik/test/162.png
#   inflating: /content/drive/MyDrive/sputnik/test/163.png
#   inflating: /content/drive/MyDrive/sputnik/test/180.png
#   inflating: /content/drive/MyDrive/sputnik/test/182.png
#   inflating: /content/drive/MyDrive/sputnik/test/184.png
#   inflating: /content/drive/MyDrive/sputnik/test/187.png
#   inflating: /content/drive/MyDrive/sputnik/test/191.png
#   inflating: /content/drive/MyDrive/sputnik/test/192.png
#   inflating: /content/drive/MyDrive/sputnik/test/194.png
#   inflating: /content/drive/MyDrive/sputnik/test/200.png
#   inflating: /content/drive/MyDrive/sputnik/test/203.png
#   inflating: /content/drive/MyDrive/sputnik/test/204.png
#   inflating: /content/drive/MyDrive/sputnik/test/205.png
#   inflating: /content/drive/MyDrive/sputnik/test/206.png
#   inflating: /content/drive/MyDrive/sputnik/test/207.png
#   inflating: /content/drive/MyDrive/sputnik/test/211.png
#   inflating: /content/drive/MyDrive/sputnik/test/212.png
#   inflating: /content/drive/MyDrive/sputnik/test/214.png
#   inflating: /content/drive/MyDrive/sputnik/test/215.png
#   inflating: /content/drive/MyDrive/sputnik/test/218.png
#   inflating: /content/drive/MyDrive/sputnik/test/221.png
#   inflating: /content/drive/MyDrive/sputnik/test/223.png
#   inflating: /content/drive/MyDrive/sputnik/test/224.png
#   inflating: /content/drive/MyDrive/sputnik/test/231.png
#   inflating: /content/drive/MyDrive/sputnik/test/232.png
#   inflating: /content/drive/MyDrive/sputnik/test/234.png
#   inflating: /content/drive/MyDrive/sputnik/test/235.png
#   inflating: /content/drive/MyDrive/sputnik/test/239.png
#   inflating: /content/drive/MyDrive/sputnik/test/242.png
#   inflating: /content/drive/MyDrive/sputnik/test/243.png
#   inflating: /content/drive/MyDrive/sputnik/test/246.png
#   inflating: /content/drive/MyDrive/sputnik/test/249.png
#   inflating: /content/drive/MyDrive/sputnik/test/250.png
#   inflating: /content/drive/MyDrive/sputnik/test/256.png
#   inflating: /content/drive/MyDrive/sputnik/test/258.png
#   inflating: /content/drive/MyDrive/sputnik/test/259.png
#   inflating: /content/drive/MyDrive/sputnik/test/260.png
#   inflating: /content/drive/MyDrive/sputnik/test/261.png
#   inflating: /content/drive/MyDrive/sputnik/test/262.png
#   inflating: /content/drive/MyDrive/sputnik/test/265.png
#   inflating: /content/drive/MyDrive/sputnik/test/269.png
#   inflating: /content/drive/MyDrive/sputnik/test/271.png
#   inflating: /content/drive/MyDrive/sputnik/test/272.png
#   inflating: /content/drive/MyDrive/sputnik/test/274.png
#   inflating: /content/drive/MyDrive/sputnik/test/276.png
#   inflating: /content/drive/MyDrive/sputnik/test/277.png
#   inflating: /content/drive/MyDrive/sputnik/test/282.png
#   inflating: /content/drive/MyDrive/sputnik/test/291.png
#   inflating: /content/drive/MyDrive/sputnik/test/292.png
#   inflating: /content/drive/MyDrive/sputnik/test/295.png
#   inflating: /content/drive/MyDrive/sputnik/test/298.png
#   inflating: /content/drive/MyDrive/sputnik/test/302.png
#   inflating: /content/drive/MyDrive/sputnik/test/306.png
#   inflating: /content/drive/MyDrive/sputnik/test/307.png
#   inflating: /content/drive/MyDrive/sputnik/test/310.png
#   inflating: /content/drive/MyDrive/sputnik/test/311.png
#   inflating: /content/drive/MyDrive/sputnik/test/316.png
#   inflating: /content/drive/MyDrive/sputnik/test/318.png
#   inflating: /content/drive/MyDrive/sputnik/test/320.png
#   inflating: /content/drive/MyDrive/sputnik/test/321.png
#   inflating: /content/drive/MyDrive/sputnik/test/323.png
#   inflating: /content/drive/MyDrive/sputnik/test/325.png
#   inflating: /content/drive/MyDrive/sputnik/test/328.png
#   inflating: /content/drive/MyDrive/sputnik/test/331.png
#   inflating: /content/drive/MyDrive/sputnik/test/333.png
#   inflating: /content/drive/MyDrive/sputnik/test/341.png
#   inflating: /content/drive/MyDrive/sputnik/test/342.png
#   inflating: /content/drive/MyDrive/sputnik/test/345.png
#   inflating: /content/drive/MyDrive/sputnik/test/347.png
#   inflating: /content/drive/MyDrive/sputnik/test/348.png
#   inflating: /content/drive/MyDrive/sputnik/test/349.png
#   inflating: /content/drive/MyDrive/sputnik/test/350.png
#   inflating: /content/drive/MyDrive/sputnik/test/355.png
#   inflating: /content/drive/MyDrive/sputnik/test/359.png
#   inflating: /content/drive/MyDrive/sputnik/test/361.png
#   inflating: /content/drive/MyDrive/sputnik/test/364.png
#   inflating: /content/drive/MyDrive/sputnik/test/366.png
#   inflating: /content/drive/MyDrive/sputnik/test/368.png
#   inflating: /content/drive/MyDrive/sputnik/test/370.png
#   inflating: /content/drive/MyDrive/sputnik/test/375.png
#   inflating: /content/drive/MyDrive/sputnik/test/382.png
#   inflating: /content/drive/MyDrive/sputnik/test/388.png
#   inflating: /content/drive/MyDrive/sputnik/test/390.png
#   inflating: /content/drive/MyDrive/sputnik/test/391.png
#   inflating: /content/drive/MyDrive/sputnik/test/397.png
#   inflating: /content/drive/MyDrive/sputnik/test/400.png
#   inflating: /content/drive/MyDrive/sputnik/test/403.png
#   inflating: /content/drive/MyDrive/sputnik/test/404.png
#   inflating: /content/drive/MyDrive/sputnik/test/410.png
#   inflating: /content/drive/MyDrive/sputnik/test/412.png
#   inflating: /content/drive/MyDrive/sputnik/test/415.png
#   inflating: /content/drive/MyDrive/sputnik/test/417.png
#   inflating: /content/drive/MyDrive/sputnik/test/418.png
#   inflating: /content/drive/MyDrive/sputnik/test/419.png
#   inflating: /content/drive/MyDrive/sputnik/test/425.png
#   inflating: /content/drive/MyDrive/sputnik/test/430.png
#   inflating: /content/drive/MyDrive/sputnik/test/437.png
#   inflating: /content/drive/MyDrive/sputnik/test/439.png
#   inflating: /content/drive/MyDrive/sputnik/test/440.png
#   inflating: /content/drive/MyDrive/sputnik/test/447.png
#   inflating: /content/drive/MyDrive/sputnik/test/462.png
#   inflating: /content/drive/MyDrive/sputnik/test/463.png
#   inflating: /content/drive/MyDrive/sputnik/test/470.png
#   inflating: /content/drive/MyDrive/sputnik/test/471.png
#   inflating: /content/drive/MyDrive/sputnik/test/472.png
#   inflating: /content/drive/MyDrive/sputnik/test/476.png
#   inflating: /content/drive/MyDrive/sputnik/test/477.png
#   inflating: /content/drive/MyDrive/sputnik/test/482.png
#   inflating: /content/drive/MyDrive/sputnik/test/483.png
#   inflating: /content/drive/MyDrive/sputnik/test/485.png
#   inflating: /content/drive/MyDrive/sputnik/test/487.png
#   inflating: /content/drive/MyDrive/sputnik/test/490.png
#   inflating: /content/drive/MyDrive/sputnik/test/494.png
#   inflating: /content/drive/MyDrive/sputnik/test/495.png
#   inflating: /content/drive/MyDrive/sputnik/test/497.png
#   inflating: /content/drive/MyDrive/sputnik/test/498.png
#   inflating: /content/drive/MyDrive/sputnik/test/499.png
#   inflating: /content/drive/MyDrive/sputnik/test/501.png
#   inflating: /content/drive/MyDrive/sputnik/test/517.png
#   inflating: /content/drive/MyDrive/sputnik/test/523.png
#   inflating: /content/drive/MyDrive/sputnik/test/524.png
#   inflating: /content/drive/MyDrive/sputnik/test/525.png
#   inflating: /content/drive/MyDrive/sputnik/test/531.png
#   inflating: /content/drive/MyDrive/sputnik/test/532.png
#   inflating: /content/drive/MyDrive/sputnik/test/534.png
#   inflating: /content/drive/MyDrive/sputnik/test/539.png
#   inflating: /content/drive/MyDrive/sputnik/test/541.png
#   inflating: /content/drive/MyDrive/sputnik/test/542.png
#   inflating: /content/drive/MyDrive/sputnik/test/543.png
#   inflating: /content/drive/MyDrive/sputnik/test/548.png
#   inflating: /content/drive/MyDrive/sputnik/test/551.png
#   inflating: /content/drive/MyDrive/sputnik/test/553.png
#   inflating: /content/drive/MyDrive/sputnik/test/560.png
#   inflating: /content/drive/MyDrive/sputnik/test/562.png
#   inflating: /content/drive/MyDrive/sputnik/test/567.png
#   inflating: /content/drive/MyDrive/sputnik/test/569.png
#   inflating: /content/drive/MyDrive/sputnik/test/571.png
#   inflating: /content/drive/MyDrive/sputnik/test/574.png
#   inflating: /content/drive/MyDrive/sputnik/test/575.png
#   inflating: /content/drive/MyDrive/sputnik/test/578.png
#   inflating: /content/drive/MyDrive/sputnik/test/582.png
#   inflating: /content/drive/MyDrive/sputnik/test/587.png
#   inflating: /content/drive/MyDrive/sputnik/test/588.png
#   inflating: /content/drive/MyDrive/sputnik/test/589.png
#   inflating: /content/drive/MyDrive/sputnik/test/590.png
#   inflating: /content/drive/MyDrive/sputnik/test/599.png
#   inflating: /content/drive/MyDrive/sputnik/test/600.png
#   inflating: /content/drive/MyDrive/sputnik/test/603.png
#   inflating: /content/drive/MyDrive/sputnik/test/605.png
#   inflating: /content/drive/MyDrive/sputnik/test/607.png
#   inflating: /content/drive/MyDrive/sputnik/test/609.png
#   inflating: /content/drive/MyDrive/sputnik/test/617.png
#   inflating: /content/drive/MyDrive/sputnik/test/621.png
#   inflating: /content/drive/MyDrive/sputnik/test/622.png
#   inflating: /content/drive/MyDrive/sputnik/test/624.png
#   inflating: /content/drive/MyDrive/sputnik/test/631.png
#   inflating: /content/drive/MyDrive/sputnik/test/632.png
#   inflating: /content/drive/MyDrive/sputnik/test/633.png
#   inflating: /content/drive/MyDrive/sputnik/test/642.png
#   inflating: /content/drive/MyDrive/sputnik/test/643.png
#   inflating: /content/drive/MyDrive/sputnik/test/645.png
#   inflating: /content/drive/MyDrive/sputnik/test/647.png
#   inflating: /content/drive/MyDrive/sputnik/test/648.png
#   inflating: /content/drive/MyDrive/sputnik/test/649.png
#   inflating: /content/drive/MyDrive/sputnik/test/650.png
#   inflating: /content/drive/MyDrive/sputnik/test/654.png
#   inflating: /content/drive/MyDrive/sputnik/test/655.png
#   inflating: /content/drive/MyDrive/sputnik/test/656.png
#   inflating: /content/drive/MyDrive/sputnik/test/660.png
#   inflating: /content/drive/MyDrive/sputnik/test/662.png
#   inflating: /content/drive/MyDrive/sputnik/test/663.png
#   inflating: /content/drive/MyDrive/sputnik/test/668.png
#   inflating: /content/drive/MyDrive/sputnik/test/669.png
#   inflating: /content/drive/MyDrive/sputnik/test/670.png
#   inflating: /content/drive/MyDrive/sputnik/test/671.png
#   inflating: /content/drive/MyDrive/sputnik/test/674.png
#   inflating: /content/drive/MyDrive/sputnik/test/678.png
#   inflating: /content/drive/MyDrive/sputnik/test/679.png
#   inflating: /content/drive/MyDrive/sputnik/test/682.png
#   inflating: /content/drive/MyDrive/sputnik/test/684.png
#   inflating: /content/drive/MyDrive/sputnik/test/686.png
#   inflating: /content/drive/MyDrive/sputnik/test/694.png
#   inflating: /content/drive/MyDrive/sputnik/test/696.png
#   inflating: /content/drive/MyDrive/sputnik/test/697.png
#   inflating: /content/drive/MyDrive/sputnik/test/703.png
#   inflating: /content/drive/MyDrive/sputnik/test/704.png
#   inflating: /content/drive/MyDrive/sputnik/test/706.png
#   inflating: /content/drive/MyDrive/sputnik/test/707.png
#   inflating: /content/drive/MyDrive/sputnik/test/708.png
#   inflating: /content/drive/MyDrive/sputnik/test/710.png
#   inflating: /content/drive/MyDrive/sputnik/test/711.png
#   inflating: /content/drive/MyDrive/sputnik/test/713.png
#   inflating: /content/drive/MyDrive/sputnik/test/714.png
#   inflating: /content/drive/MyDrive/sputnik/test/715.png
#   inflating: /content/drive/MyDrive/sputnik/test/716.png
#   inflating: /content/drive/MyDrive/sputnik/test/723.png
#   inflating: /content/drive/MyDrive/sputnik/test/727.png
#   inflating: /content/drive/MyDrive/sputnik/test/733.png
#   inflating: /content/drive/MyDrive/sputnik/test/736.png
#   inflating: /content/drive/MyDrive/sputnik/test/742.png
#   inflating: /content/drive/MyDrive/sputnik/test/747.png
#   inflating: /content/drive/MyDrive/sputnik/test/748.png
#   inflating: /content/drive/MyDrive/sputnik/test/755.png
#   inflating: /content/drive/MyDrive/sputnik/test/758.png
#   inflating: /content/drive/MyDrive/sputnik/test/760.png
#   inflating: /content/drive/MyDrive/sputnik/test/762.png
#   inflating: /content/drive/MyDrive/sputnik/test/763.png
#   inflating: /content/drive/MyDrive/sputnik/test/767.png
#   inflating: /content/drive/MyDrive/sputnik/test/771.png
#   inflating: /content/drive/MyDrive/sputnik/test/773.png
#   inflating: /content/drive/MyDrive/sputnik/test/777.png
#   inflating: /content/drive/MyDrive/sputnik/test/780.png
#   inflating: /content/drive/MyDrive/sputnik/test/783.png
#   inflating: /content/drive/MyDrive/sputnik/test/784.png
#   inflating: /content/drive/MyDrive/sputnik/test/787.png
#   inflating: /content/drive/MyDrive/sputnik/test/789.png
#   inflating: /content/drive/MyDrive/sputnik/test/790.png
#   inflating: /content/drive/MyDrive/sputnik/test/797.png
#   inflating: /content/drive/MyDrive/sputnik/test/798.png
#   inflating: /content/drive/MyDrive/sputnik/test/802.png
#   inflating: /content/drive/MyDrive/sputnik/test/803.png
#   inflating: /content/drive/MyDrive/sputnik/test/804.png
#   inflating: /content/drive/MyDrive/sputnik/test/805.png
#   inflating: /content/drive/MyDrive/sputnik/test/806.png
#   inflating: /content/drive/MyDrive/sputnik/test/807.png
#   inflating: /content/drive/MyDrive/sputnik/test/809.png
#   inflating: /content/drive/MyDrive/sputnik/test/810.png
#   inflating: /content/drive/MyDrive/sputnik/test/813.png
#   inflating: /content/drive/MyDrive/sputnik/test/814.png
#   inflating: /content/drive/MyDrive/sputnik/test/815.png
#   inflating: /content/drive/MyDrive/sputnik/test/817.png
#   inflating: /content/drive/MyDrive/sputnik/test/818.png
#   inflating: /content/drive/MyDrive/sputnik/test/819.png
#   inflating: /content/drive/MyDrive/sputnik/test/832.png
#   inflating: /content/drive/MyDrive/sputnik/test/836.png
#   inflating: /content/drive/MyDrive/sputnik/test/837.png
#   inflating: /content/drive/MyDrive/sputnik/test/845.png
#   inflating: /content/drive/MyDrive/sputnik/test/846.png
#   inflating: /content/drive/MyDrive/sputnik/test/850.png
#   inflating: /content/drive/MyDrive/sputnik/test/851.png
#   inflating: /content/drive/MyDrive/sputnik/test/855.png
#   inflating: /content/drive/MyDrive/sputnik/test/858.png
#   inflating: /content/drive/MyDrive/sputnik/test/861.png
#   inflating: /content/drive/MyDrive/sputnik/test/862.png
#   inflating: /content/drive/MyDrive/sputnik/test/864.png
#   inflating: /content/drive/MyDrive/sputnik/test/868.png
#   inflating: /content/drive/MyDrive/sputnik/test/869.png
#   inflating: /content/drive/MyDrive/sputnik/test/870.png
#   inflating: /content/drive/MyDrive/sputnik/test/871.png
#   inflating: /content/drive/MyDrive/sputnik/test/872.png
#   inflating: /content/drive/MyDrive/sputnik/test/877.png
#   inflating: /content/drive/MyDrive/sputnik/test/880.png
#   inflating: /content/drive/MyDrive/sputnik/test/881.png
#   inflating: /content/drive/MyDrive/sputnik/test/882.png
#   inflating: /content/drive/MyDrive/sputnik/test/885.png
#   inflating: /content/drive/MyDrive/sputnik/test/886.png
#   inflating: /content/drive/MyDrive/sputnik/test/888.png
#   inflating: /content/drive/MyDrive/sputnik/test/891.png
#   inflating: /content/drive/MyDrive/sputnik/test/896.png
#   inflating: /content/drive/MyDrive/sputnik/test/901.png
#   inflating: /content/drive/MyDrive/sputnik/test/902.png
#   inflating: /content/drive/MyDrive/sputnik/test/904.png
#   inflating: /content/drive/MyDrive/sputnik/test/906.png
#   inflating: /content/drive/MyDrive/sputnik/test/910.png
#   inflating: /content/drive/MyDrive/sputnik/test/918.png
#   inflating: /content/drive/MyDrive/sputnik/test/919.png
#   inflating: /content/drive/MyDrive/sputnik/test/920.png
#   inflating: /content/drive/MyDrive/sputnik/test/921.png
#   inflating: /content/drive/MyDrive/sputnik/test/922.png
#   inflating: /content/drive/MyDrive/sputnik/test/923.png
#   inflating: /content/drive/MyDrive/sputnik/test/924.png
#   inflating: /content/drive/MyDrive/sputnik/test/927.png
#   inflating: /content/drive/MyDrive/sputnik/test/930.png
#   inflating: /content/drive/MyDrive/sputnik/test/934.png
#   inflating: /content/drive/MyDrive/sputnik/test/937.png
#   inflating: /content/drive/MyDrive/sputnik/test/940.png
#   inflating: /content/drive/MyDrive/sputnik/test/943.png
#   inflating: /content/drive/MyDrive/sputnik/test/945.png
#   inflating: /content/drive/MyDrive/sputnik/test/947.png
#   inflating: /content/drive/MyDrive/sputnik/test/948.png
#   inflating: /content/drive/MyDrive/sputnik/test/949.png
#   inflating: /content/drive/MyDrive/sputnik/test/951.png
#   inflating: /content/drive/MyDrive/sputnik/test/953.png
#   inflating: /content/drive/MyDrive/sputnik/test/955.png
#   inflating: /content/drive/MyDrive/sputnik/test/960.png
#   inflating: /content/drive/MyDrive/sputnik/test/963.png
#   inflating: /content/drive/MyDrive/sputnik/test/965.png
#   inflating: /content/drive/MyDrive/sputnik/test/969.png
#   inflating: /content/drive/MyDrive/sputnik/test/972.png
#   inflating: /content/drive/MyDrive/sputnik/test/978.png
#   inflating: /content/drive/MyDrive/sputnik/test/979.png
#   inflating: /content/drive/MyDrive/sputnik/test/986.png
#   inflating: /content/drive/MyDrive/sputnik/test/987.png
#   inflating: /content/drive/MyDrive/sputnik/test/992.png
#   inflating: /content/drive/MyDrive/sputnik/test/999.png
#   inflating: /content/drive/MyDrive/sputnik/test/1001.png
#   inflating: /content/drive/MyDrive/sputnik/test/1002.png
#   inflating: /content/drive/MyDrive/sputnik/test/1007.png
#   inflating: /content/drive/MyDrive/sputnik/test/1010.png
#   inflating: /content/drive/MyDrive/sputnik/test/1012.png
#   inflating: /content/drive/MyDrive/sputnik/test/1013.png
#   inflating: /content/drive/MyDrive/sputnik/test/1014.png
#   inflating: /content/drive/MyDrive/sputnik/test/1017.png
#   inflating: /content/drive/MyDrive/sputnik/test/1018.png
#   inflating: /content/drive/MyDrive/sputnik/test/1021.png
#   inflating: /content/drive/MyDrive/sputnik/test/1025.png
#   inflating: /content/drive/MyDrive/sputnik/test/1031.png
#   inflating: /content/drive/MyDrive/sputnik/test/1034.png
#   inflating: /content/drive/MyDrive/sputnik/test/1037.png
#   inflating: /content/drive/MyDrive/sputnik/test/1040.png
#   inflating: /content/drive/MyDrive/sputnik/test/1041.png
#   inflating: /content/drive/MyDrive/sputnik/test/1043.png
#   inflating: /content/drive/MyDrive/sputnik/test/1047.png
#   inflating: /content/drive/MyDrive/sputnik/test/1049.png
#   inflating: /content/drive/MyDrive/sputnik/test/1057.png
#   inflating: /content/drive/MyDrive/sputnik/test/1062.png
#   inflating: /content/drive/MyDrive/sputnik/test/1063.png
#   inflating: /content/drive/MyDrive/sputnik/test/1068.png
#   inflating: /content/drive/MyDrive/sputnik/test/1070.png
#   inflating: /content/drive/MyDrive/sputnik/test/1074.png
#   inflating: /content/drive/MyDrive/sputnik/test/1077.png
#   inflating: /content/drive/MyDrive/sputnik/test/1083.png
#   inflating: /content/drive/MyDrive/sputnik/test/1086.png
#   inflating: /content/drive/MyDrive/sputnik/test/1090.png
#   inflating: /content/drive/MyDrive/sputnik/test/1099.png
#   inflating: /content/drive/MyDrive/sputnik/test/1102.png
#   inflating: /content/drive/MyDrive/sputnik/test/1106.png
#   inflating: /content/drive/MyDrive/sputnik/test/1107.png
#   inflating: /content/drive/MyDrive/sputnik/test/1114.png
#   inflating: /content/drive/MyDrive/sputnik/test/1117.png
#   inflating: /content/drive/MyDrive/sputnik/test/1120.png
#   inflating: /content/drive/MyDrive/sputnik/test/1126.png
#   inflating: /content/drive/MyDrive/sputnik/test/1128.png
#   inflating: /content/drive/MyDrive/sputnik/test/1132.png
#   inflating: /content/drive/MyDrive/sputnik/test/1134.png
#   inflating: /content/drive/MyDrive/sputnik/test/1135.png
#   inflating: /content/drive/MyDrive/sputnik/test/1144.png
#   inflating: /content/drive/MyDrive/sputnik/test/1149.png
#   inflating: /content/drive/MyDrive/sputnik/test/1155.png
#   inflating: /content/drive/MyDrive/sputnik/test/1173.png
#   inflating: /content/drive/MyDrive/sputnik/test/1177.png
#   inflating: /content/drive/MyDrive/sputnik/test/1179.png
#   inflating: /content/drive/MyDrive/sputnik/test/1192.png
#   inflating: /content/drive/MyDrive/sputnik/test/1193.png
#   inflating: /content/drive/MyDrive/sputnik/test/1196.png

# %% [markdown]
# ## Аугументация

# %%
import imageio
import imgaug.augmenters as iaa
from imgaug import augmenters as iaa

# %%
file_source = '/content/drive/MyDrive/sputnik/train/img/'
get_files = os.listdir(file_source)
# for i in get_files:
#   print(int(i.split('.')[0]))
for j in range(3): 
  for i in tqdm(range(800)):
    # i = int(i.split('.')[0])
    image_name, labels = data_df.iloc[i]['id'], [data_df.iloc[i]['left_top_x'], 
                                                                data_df.iloc[i]['left_top_y'], 
                                                                data_df.iloc[i]['right_top_x'], 
                                                                data_df.iloc[i]['right_top_y'],
                                                                data_df.iloc[i]['left_bottom_x'], 
                                                                data_df.iloc[i]['left_bottom_y'],  
                                                                data_df.iloc[i]['right_bottom_x'], 
                                                                data_df.iloc[i]['right_bottom_y'], 
                                                                data_df.iloc[i]['angle']]

    
    # читаем картинку. read the image
    image = cv2.imread(f"/content/drive/MyDrive/sputnik/train/img/{image_name}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    augimg = seq.augment(image=image)
    # plt.imshow(image)

    data = {}
    data['left_top'] = []
    data['right_top'] = []
    data['left_bottom'] = []
    data['right_bottom'] = [] 
    data['angle'] = []  

    data['left_top'] = ([labels[0],labels[1]])
    data['right_top'] = ([labels[2],labels[3]])
    data['left_bottom'] = ([labels[4],labels[5]])
    data['right_bottom'] = ([labels[6],labels[7]]) 
    data['angle'] = (labels[8])  

    sub_dir = f"/content/json{j}/"
    if not os.path.exists(sub_dir):
        os.makedirs(sub_dir)
    with open(f'/content/json{j}/out_{j}_{i}.json', 'w') as outfile:
      json.dump(data, outfile)
      
    sub_dir1 = f"/content/img{j}/"
    if not os.path.exists(sub_dir1):
        os.makedirs(sub_dir1)
    unique, counts = np.unique(augimg, return_counts=True)
    if len(counts) > 0 and counts[0]/counts.sum() < .1:
      cv2.imwrite(f'/content/img{j}/out_{j}_{i}.png', augimg)

# %% [markdown]
# ## Тренировочный Датасет

# %%
json_dir = "/content/drive/MyDrive/sputnik/train/json/"

data_df = pd.DataFrame({'id': [],
                        'center_x' : [],
                        'center_y' : [],
                        'angle': []})

json_true = []
for _, _, files in os.walk(json_dir):
  for x in files:
    if x.endswith(".json"):
      data = json.load(open(json_dir + x))
      if 'data' in x:
          new_row = {'id':f'out_{x.split("_")[1]}_{x.split("_")[2]}_{x.split("_")[3][:-5]}.png',
                     'center_x' : (data["left_top"][0] + data["right_top"][0] + data["left_bottom"][0] + data["right_bottom"][0])/4,
                     'center_y' : (data["left_top"][1] + data["right_top"][1] + data["left_bottom"][1] + data["right_bottom"][1])/4,
                     'angle': data["angle"]}
      else:
         new_row = {'id':x.split(".")[0]+".png",
                    'center_x' : (data["left_top"][0] + data["right_top"][0] + data["left_bottom"][0] + data["right_bottom"][0])/4,
                    'center_y' : (data["left_top"][1] + data["right_top"][1] + data["left_bottom"][1] + data["right_bottom"][1])/4,
                    'angle': data["angle"]}
                    
      data_df = data_df.append(new_row, ignore_index=True)

# %%
data_df
# Out:
#            id  center_x  center_y  angle
# 0       1.png    9183.5    2501.5  341.0
# 1     100.png    7337.5    4113.5  246.0
# 2    1000.png    6190.5    9573.5   53.0
# 3    1003.png    5844.5    7282.5  215.0
# 4    1004.png    5499.5    9360.5  356.0
# ..        ...       ...       ...    ...
# 795   994.png    4523.5    2579.5  345.0
# 796   995.png    6827.5    5562.5  272.0
# 797   996.png    5536.5    7868.5  148.0
# 798   997.png    4337.5    3738.5  338.0
# 799   998.png    2491.5    6750.5  305.0
#
# [800 rows x 4 columns]

# %%
class ImageDataset(Dataset):
    def __init__(self, data_df, transform=None):

        self.data_df = data_df
        self.transform = transform

    def __getitem__(self, idx):
        # достаем имя изображения и ее лейбл
        image_name, labels = self.data_df.iloc[idx]['id'], [self.data_df.iloc[idx]['center_x']/10496, 
                                                            self.data_df.iloc[idx]['center_y']/10496, 
                                                            self.data_df.iloc[idx]['angle']/360]

        # читаем картинку. read the image
        image = cv2.imread(f"/content/drive/MyDrive/sputnik/train/img/{image_name}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        
        # преобразуем, если нужно. transform it, if necessary
        if self.transform:
            image = self.transform(image)
        
        return image, torch.tensor(labels).float()
    
    def __len__(self):
        return len(self.data_df)

# %%
# задаем преобразование изображения.

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(380),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                          std=[0.229, 0.224, 0.225]),
])

valid_transform = transforms.Compose([
    transforms.RandomResizedCrop(380),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                          std=[0.229, 0.224, 0.225]),
])

# %%
# читаем датасет
# data_df = pd.read_csv("/content/train.csv")

# %%
from os import listdir

print("Обучающей выборки " ,len(listdir("/content/drive/MyDrive/sputnik/train/img/")))
print("Тестовой выборки " ,len(listdir("/content/drive/MyDrive/sputnik/test/")))
# Out:
# Обучающей выборки  800
# Тестовой выборки  400

# %%
# разделим датасет на трейн и валидацию, чтобы смотреть на качество
train_df, valid_df = train_test_split(data_df, test_size=0.1)#, random_state=333)

# %%
train_df.shape, valid_df.shape
# Out:
# ((720, 4), (80, 4))

# %%
train_dataset = ImageDataset(train_df, train_transform)
valid_dataset = ImageDataset(valid_df, valid_transform)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=16,
                                           shuffle=True,
                                           pin_memory=True,
                                           num_workers=2)

valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset,
                                           batch_size=16,
                                           # shuffle=True,
                                           pin_memory=True,
                                           num_workers=2)

# %% [markdown]
# ## Вспомогательные функции

# %%
def compute_metric(data_true, data_pred, outImageW = 10496, outImageH = 10496):

    x_center_true = np.array(data_true[0]).astype(int)
    y_center_true = np.array(data_true[1]).astype(int)

    x_metr = x_center_true - np.array(data_pred[0]).astype(int)
    y_metr = y_center_true - np.array(data_pred[1]).astype(int)

    metr =  1 - (0.7 * (abs(x_metr)/outImageH + abs(y_metr)/outImageW)/2 + 0.3 *abs(data_pred[2] - data_true[2])/360)
    return metr

# %%
def plot_history(train_history, val_history, title='loss'):
    plt.figure()
    plt.title('{}'.format(title))
    plt.plot(train_history, label='train', zorder=1)
    
    points = np.array(val_history)
    steps = list(range(0, len(train_history) + 1, int(len(train_history) / len(val_history))))[1:]
    
    plt.scatter(steps, val_history, marker='+', s=180, c='orange', label='val', zorder=2)
    plt.xlabel('train steps')
    
    plt.legend(loc='best')
    plt.grid()

    plt.show()

# %%
def train(model, criterion, optimizer, train_dataloader, test_dataloader, NUM_EPOCH=15):
    train_loss_log = []
    val_loss_log = []
    
    train_acc_log = []
    val_acc_log = []
    

    for epoch in tqdm(range(NUM_EPOCH)):
        model.train()
        train_loss = 0.
        train_size = 0
        
        train_pred = []

        for imgs, labels in train_dataloader:
            optimizer.zero_grad()

            imgs = imgs.cuda()
            labels = labels.cuda()

            y_pred = model(imgs)

            loss = criterion(y_pred, labels)
            loss.backward()
            
            train_loss += loss.item()
            train_size += y_pred.size(0)
            train_loss_log.append((loss.data.cpu().detach().numpy() / y_pred.size(0)) * 100)
            
            y_pred[:, :2] = y_pred[:, :2] * 10496
            y_pred[:, -1] = y_pred[:, -1] * 360

            labels[:, :2] = labels[:, :2] * 10496
            labels[:, -1] = labels[:, -1] * 360

            for label, pr in zip(labels, y_pred):
                    train_pred.append(compute_metric(label.cpu().detach().numpy(), pr.cpu().detach().numpy()))

            optimizer.step()

        train_acc_log.append(train_pred)

        val_loss = 0.
        val_size = 0
        
        val_pred = []
        
        model.eval()
        
        with torch.no_grad():
            for imgs, labels in test_dataloader:
                
                imgs = imgs.cuda()
                labels = labels.cuda()
                
                pred = model(imgs)
                loss = criterion(pred, labels)

                pred[:, :2] = pred[:, :2] * 10496
                pred[:, -1] = pred[:, -1] * 360

                labels[:, :2] = labels[:, :2] * 10496
                labels[:, -1] = labels[:, -1] * 360
                
                val_loss += loss.item()
                val_size += pred.size(0)

                for label, pr in zip(labels, pred):
                    val_pred.append(compute_metric(label.cpu().detach().numpy(), pr.cpu().detach().numpy()))

        val_loss_log.append((val_loss / val_size)*100)
        val_acc_log.append(val_pred)

        clear_output()
        plot_history(train_loss_log, val_loss_log, 'loss')

        print('Train loss:', (train_loss / train_size)*100)
        print('Val loss:', (val_loss / val_size)*100)
        print('Train metric:', (np.mean(train_pred)))
        print('Val metric:', (np.mean(val_pred)))
        
    return train_loss_log, train_acc_log, val_loss_log, val_acc_log

# %% [markdown]
# ## Модель

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## EfficentNet

# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (4.1.1)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=856800b179777d80174c7586660c5db7a390ab3e3a181c5870dbd5c37d0c1420
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
from efficientnet_pytorch import EfficientNet

# %%
model = EfficientNet.from_pretrained('efficientnet-b4')
last = model._fc
model._fc = nn.Linear(last.in_features, 3)
model.load_state_dict(torch.load('/content/drive/MyDrive/sputnik/model2/weights2.pth'))
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b4-6ed6700e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b4-6ed6700e.pth
#   0%|          | 0.00/74.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b4
# <All keys matched successfully>

# %%
model
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 48, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         48, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         24, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 24, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(5, 5), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(5, 5), stride=(1, 1), groups=336, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         336, 336, kernel_size=(3, 3), stride=[2, 2], groups=336, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(336, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         336, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 336, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(3, 3), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[1, 1], groups=672, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[2, 2], groups=960, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(5, 5), stride=(1, 1), groups=1632, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(272, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1632, 1632, kernel_size=(3, 3), stride=[1, 1], groups=1632, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(1632, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1632, 68, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         68, 1632, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2688, 2688, kernel_size=(3, 3), stride=(1, 1), groups=2688, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(2688, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2688, 112, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         112, 2688, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(448, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1792, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.4, inplace=False)
#   (_fc): Linear(in_features=1792, out_features=3, bias=True)
#   (_swish): MemoryEfficientSwish()
# )

# %%
model = model.cuda()

# %%
criterion = torch.nn.MSELoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

# %%
torch.cuda.empty_cache()

# %%
train_loss_log, train_acc_log, val_loss_log, val_acc_log = train(model, 
                                                                 criterion, 
                                                                 optimizer, 
                                                                 train_loader, 
                                                                 valid_loader, 
                                                                 15)
# Out:
#  20%|██        | 3/15 [02:13<08:54, 44.55s/it]
# Train loss: 0.023748161846823577
# Val loss: 0.01718041326967068
# Train metric: 0.954640549786362
# Val metric: 0.9628021292249119

# %%
torch.save(model, '/content/drive/MyDrive/sputnik/model2/weights2.pth')

# %% [markdown]
# ## Посчитаем метрику

# %%
total_metric = []

for imgs, labels in valid_loader:
    imgs = imgs.cuda()
    labels = labels.cpu().detach().numpy()            
    pred = model(imgs)
    pred = pred.cpu().detach().numpy()    

    pred[:, :2] = pred[:, :2] * 10496
    pred[:, -1] = pred[:, -1] * 360

    labels[:, :2] = labels[:, :2] * 10496
    labels[:, -1] = labels[:, -1] * 360
    
    for label, pr in zip(labels, pred):
        total_metric.append(compute_metric(label, pr))
    
total_metric = np.mean(total_metric)
print('Valid metric:', total_metric)
# Out:
# Valid metric: 0.942981962690024

# %% [markdown]
# # Создадим предсказания на тестовом наборе данных

# %%
class TestImageDataset(Dataset):
    def __init__(self, files, transform=None):

        self.files = files
        self.transform = transform

    def __getitem__(self, idx):

        image_name = self.files[idx]

        # читаем картинку. read the image
        image = cv2.imread(f"/content/drive/MyDrive/sputnik/test/{image_name}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        
        # преобразуем, если нужно. transform it, if necessary
        if self.transform:
            image = self.transform(image)
        
        return image
    
    def __len__(self):
        return len(self.files)

# %%
test_images_dir = '/content/drive/MyDrive/sputnik/test/'

for _, _, test_files in os.walk(test_images_dir):
    break

test_dataset = TestImageDataset(test_files, valid_transform)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=4,
                                           # shuffle=True,
                                           pin_memory=True,
                                           num_workers=2
                                           )

# %%
indexes = [x.split('.')[0] for x in test_files]
preds = []

for imgs in test_loader:
    imgs = imgs.cuda()            
    pred = model(imgs)
    pred = pred.cpu().detach().numpy()
    pred[:, :2] = np.clip(pred[:, :2] * 10496, 0, 10496)
    pred[:, -1] = np.clip(pred[:, -1] * 360, 0, 360)
    preds.extend(list(pred))

# %%
sub_dir = "/content/submission/"
if not os.path.exists(sub_dir):
    os.makedirs(sub_dir)

json_true = []

for indx, pred in zip(indexes, preds):

    pred = [int(x) for x in pred]

    left_top = [pred[0], pred[1]]
    right_top = [pred[0], pred[1]]
    left_bottom = [pred[0], pred[1]]
    right_bottom = [pred[0], pred[1]]
        
    res = {
        'left_top': left_top,
        'right_top': right_top,
        'left_bottom': left_bottom,
        'right_bottom': right_bottom,
        'angle': pred[2]
    }

    with open(sub_dir+indx+'.json', 'w') as f:
        json.dump(res, f)

# %%
# !zip -r /content/submission.zip /content/submission
